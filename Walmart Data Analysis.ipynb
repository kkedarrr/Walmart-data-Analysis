# %% [markdown]
# #### Importing modules needed for the walmart analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Reading the data from file

# %%
d=pd.read_excel(r'C:\Users\user\Desktop\walmart Retail Data.xlsx')

# %%
d
# Out:
#                 City  Customer Age      Customer Name Customer Segment  \
# 0         McKeesport           NaN     Jessica Myrick   Small Business
# 1              Bowie           NaN     Matt Collister      Home Office
# 2               Napa           NaN  Alan Schoenberger        Corporate
# 3         Montebello           NaN  Elizabeth Moffitt         Consumer
# 4               Napa           NaN  Alan Schoenberger        Corporate
# ...              ...           ...                ...              ...
# 8394       Fairfield          95.0      Tony Molinari        Corporate
# 8395  Harker Heights          95.0    Matt Hagelstein      Home Office
# 8396       Riverview          95.0      Theresa Swint         Consumer
# 8397   Nicholasville          95.0    Maribeth Yedwab      Home Office
# 8398   Nicholasville          95.0    Maribeth Yedwab      Home Office
#
#       Discount  Number of Records Order Date  Order ID Order Priority  \
# ...

# %% [markdown]
# #### Final five row fetching

# %%
d.tail()
# Out:
#                 City  Customer Age    Customer Name Customer Segment  \
# 8394       Fairfield          95.0    Tony Molinari        Corporate
# 8395  Harker Heights          95.0  Matt Hagelstein      Home Office
# 8396       Riverview          95.0    Theresa Swint         Consumer
# 8397   Nicholasville          95.0  Maribeth Yedwab      Home Office
# 8398   Nicholasville          95.0  Maribeth Yedwab      Home Office
#
#       Discount  Number of Records Order Date  Order ID Order Priority  \
# 8394      0.10                  1 2015-12-30     50950  Not Specified
# 8395      0.09                  1 2015-12-30     25542            Low
# 8396      0.10                  1 2015-12-30     45127         Medium
# 8397      0.09                  1 2015-12-30     49344            Low
# 8398      0.00                  1 2015-12-30     49344            Low
#
#       Order Quantity  ...  Profit   Region Row ID   Sales  Ship Date  \
# ...

# %% [markdown]
# #### Initial 5 row fetching

# %%
d.head()
# Out:
#          City  Customer Age      Customer Name Customer Segment  Discount  \
# 0  McKeesport           NaN     Jessica Myrick   Small Business      0.10
# 1       Bowie           NaN     Matt Collister      Home Office      0.08
# 2        Napa           NaN  Alan Schoenberger        Corporate      0.00
# 3  Montebello           NaN  Elizabeth Moffitt         Consumer      0.08
# 4        Napa           NaN  Alan Schoenberger        Corporate      0.07
#
#    Number of Records Order Date  Order ID Order Priority  Order Quantity  ...  \
# 0                  1 2012-01-01     28774           High              32  ...
# 1                  1 2012-01-01     13729  Not Specified               9  ...
# 2                  1 2012-01-02     37537            Low               4  ...
# 3                  1 2012-01-02     44069       Critical              43  ...
# 4                  1 2012-01-02     37537            Low              43  ...
#
# ...

# %% [markdown]
# #### Detecting the shape, that is how much clumn and how much row exist in the data

# %%
d.shape
# Out:
# (8399, 25)

# %% [markdown]
# #### Datatype of each column

# %%
d.dtypes
# Out:
# City                            object
# Customer Age                   float64
# Customer Name                   object
# Customer Segment                object
# Discount                       float64
# Number of Records                int64
# Order Date              datetime64[ns]
# Order ID                         int64
# Order Priority                  object
# Order Quantity                   int64
# Product Base Margin            float64
# Product Category                object
# Product Container               object
# Product Name                    object
# Product Sub-Category            object
# Profit                         float64
# Region                          object
# Row ID                           int64
# Sales                          float64
# Ship Date               datetime64[ns]
# Ship Mode                       object
# Shipping Cost                  float64
# State                           object
# Unit Price                     float64
# ...

# %% [markdown]
# #### Checking null value existance

# %%
d.isnull()
# Out:
#        City  Customer Age  Customer Name  Customer Segment  Discount  \
# 0     False          True          False             False     False
# 1     False          True          False             False     False
# 2     False          True          False             False     False
# 3     False          True          False             False     False
# 4     False          True          False             False     False
# ...     ...           ...            ...               ...       ...
# 8394  False         False          False             False     False
# 8395  False         False          False             False     False
# 8396  False         False          False             False     False
# 8397  False         False          False             False     False
# 8398  False         False          False             False     False
#
#       Number of Records  Order Date  Order ID  Order Priority  Order Quantity  \
# ...

# %% [markdown]
# #### Calculating sum of null values

# %%
d.isnull().sum()
# Out:
# City                      0
# Customer Age            903
# Customer Name             0
# Customer Segment          0
# Discount                  0
# Number of Records         0
# Order Date                0
# Order ID                  0
# Order Priority            0
# Order Quantity            0
# Product Base Margin      63
# Product Category          0
# Product Container         0
# Product Name              0
# Product Sub-Category      0
# Profit                    0
# Region                    0
# Row ID                    0
# Sales                     0
# Ship Date                 0
# Ship Mode                 0
# Shipping Cost             0
# State                     0
# Unit Price                0
# Zip Code                  0
# dtype: int64

# %% [markdown]
# #### Toatal count of null value

# %%
d.isnull().sum().sum()
# Out:
# 966

# %% [markdown]
# #### Initial 10 record from the data

# %%
d.head(10)
# Out:
#           City  Customer Age      Customer Name Customer Segment  Discount  \
# 0   McKeesport           NaN     Jessica Myrick   Small Business      0.10
# 1        Bowie           NaN     Matt Collister      Home Office      0.08
# 2         Napa           NaN  Alan Schoenberger        Corporate      0.00
# 3   Montebello           NaN  Elizabeth Moffitt         Consumer      0.08
# 4         Napa           NaN  Alan Schoenberger        Corporate      0.07
# 5   Montebello           NaN  Elizabeth Moffitt         Consumer      0.09
# 6   Prior Lake           NaN     David Philippe         Consumer      0.06
# 7         Napa           NaN  Alan Schoenberger        Corporate      0.05
# 8  Phenix City           NaN      Patrick Jones      Home Office      0.09
# 9       Draper           NaN         Larry Tron      Home Office      0.05
#
#    Number of Records Order Date  Order ID Order Priority  Order Quantity  ...  \
# ...

# %% [markdown]
# #### Final 10 data from the data

# %%
d.tail(10)
# Out:
#                  City  Customer Age     Customer Name Customer Segment  \
# 8389        Scarsdale          95.0   Shirley Schmidt        Corporate
# 8390           Olathe          88.0     Anna Andreadi   Small Business
# 8391        Horn Lake          88.0  Jennifer Jackson      Home Office
# 8392        Fairfield          95.0     Tony Molinari        Corporate
# 8393  Charlottesville          95.0           Jim Epp   Small Business
# 8394        Fairfield          95.0     Tony Molinari        Corporate
# 8395   Harker Heights          95.0   Matt Hagelstein      Home Office
# 8396        Riverview          95.0     Theresa Swint         Consumer
# 8397    Nicholasville          95.0   Maribeth Yedwab      Home Office
# 8398    Nicholasville          95.0   Maribeth Yedwab      Home Office
#
#       Discount  Number of Records Order Date  Order ID Order Priority  \
# 8389      0.05                  1 2015-12-29     53730           High
# ...

# %% [markdown]
# #### Fetching information related with each column

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   City                  8399 non-null   object
#  1   Customer Age          7496 non-null   float64
#  2   Customer Name         8399 non-null   object
#  3   Customer Segment      8399 non-null   object
#  4   Discount              8399 non-null   float64
#  5   Number of Records     8399 non-null   int64
#  6   Order Date            8399 non-null   datetime64[ns]
#  7   Order ID              8399 non-null   int64
#  8   Order Priority        8399 non-null   object
#  9   Order Quantity        8399 non-null   int64
#  10  Product Base Margin   8336 non-null   float64
#  11  Product Category      8399 non-null   object
#  12  Product Container     8399 non-null   object
#  13  Product Name          8399 non-null   object
# ...

# %%
d
# Out:
#                 City  Customer Age      Customer Name Customer Segment  \
# 0         McKeesport           NaN     Jessica Myrick   Small Business
# 1              Bowie           NaN     Matt Collister      Home Office
# 2               Napa           NaN  Alan Schoenberger        Corporate
# 3         Montebello           NaN  Elizabeth Moffitt         Consumer
# 4               Napa           NaN  Alan Schoenberger        Corporate
# ...              ...           ...                ...              ...
# 8394       Fairfield          95.0      Tony Molinari        Corporate
# 8395  Harker Heights          95.0    Matt Hagelstein      Home Office
# 8396       Riverview          95.0      Theresa Swint         Consumer
# 8397   Nicholasville          95.0    Maribeth Yedwab      Home Office
# 8398   Nicholasville          95.0    Maribeth Yedwab      Home Office
#
#       Discount  Number of Records Order Date  Order ID Order Priority  \
# ...

# %% [markdown]
# #### Eliminating uncessesory columns

# %% [markdown]
# - Row id elimination

# %%
d.drop(['Row ID'],axis=1,inplace=True)

# %%
d
# Out:
#                 City  Customer Age      Customer Name Customer Segment  \
# 0         McKeesport           NaN     Jessica Myrick   Small Business
# 1              Bowie           NaN     Matt Collister      Home Office
# 2               Napa           NaN  Alan Schoenberger        Corporate
# 3         Montebello           NaN  Elizabeth Moffitt         Consumer
# 4               Napa           NaN  Alan Schoenberger        Corporate
# ...              ...           ...                ...              ...
# 8394       Fairfield          95.0      Tony Molinari        Corporate
# 8395  Harker Heights          95.0    Matt Hagelstein      Home Office
# 8396       Riverview          95.0      Theresa Swint         Consumer
# 8397   Nicholasville          95.0    Maribeth Yedwab      Home Office
# 8398   Nicholasville          95.0    Maribeth Yedwab      Home Office
#
#       Discount  Number of Records Order Date  Order ID Order Priority  \
# ...

# %% [markdown]
# - column customer age elimination

# %%
d.drop(['Customer Age'],axis=1,inplace=True)

# %%
d
# Out:
#                 City      Customer Name Customer Segment  Discount  \
# 0         McKeesport     Jessica Myrick   Small Business      0.10
# 1              Bowie     Matt Collister      Home Office      0.08
# 2               Napa  Alan Schoenberger        Corporate      0.00
# 3         Montebello  Elizabeth Moffitt         Consumer      0.08
# 4               Napa  Alan Schoenberger        Corporate      0.07
# ...              ...                ...              ...       ...
# 8394       Fairfield      Tony Molinari        Corporate      0.10
# 8395  Harker Heights    Matt Hagelstein      Home Office      0.09
# 8396       Riverview      Theresa Swint         Consumer      0.10
# 8397   Nicholasville    Maribeth Yedwab      Home Office      0.09
# 8398   Nicholasville    Maribeth Yedwab      Home Office      0.00
#
#       Number of Records Order Date  Order ID Order Priority  Order Quantity  \
# 0                     1 2012-01-01     28774           High              32
# ...

# %% [markdown]
# - Region coulumn elimination

# %%
d.drop(['Region'],axis=1,inplace=True)

# %%
d
# Out:
#                 City      Customer Name Customer Segment  Discount  \
# 0         McKeesport     Jessica Myrick   Small Business      0.10
# 1              Bowie     Matt Collister      Home Office      0.08
# 2               Napa  Alan Schoenberger        Corporate      0.00
# 3         Montebello  Elizabeth Moffitt         Consumer      0.08
# 4               Napa  Alan Schoenberger        Corporate      0.07
# ...              ...                ...              ...       ...
# 8394       Fairfield      Tony Molinari        Corporate      0.10
# 8395  Harker Heights    Matt Hagelstein      Home Office      0.09
# 8396       Riverview      Theresa Swint         Consumer      0.10
# 8397   Nicholasville    Maribeth Yedwab      Home Office      0.09
# 8398   Nicholasville    Maribeth Yedwab      Home Office      0.00
#
#       Number of Records Order Date  Order ID Order Priority  Order Quantity  \
# 0                     1 2012-01-01     28774           High              32
# ...

# %% [markdown]
# - product subcategory colum elimination

# %%
d.drop(['Product Sub-Category'],axis=1,inplace=True)

# %%
d
# Out:
#                 City      Customer Name Customer Segment  Discount  \
# 0         McKeesport     Jessica Myrick   Small Business      0.10
# 1              Bowie     Matt Collister      Home Office      0.08
# 2               Napa  Alan Schoenberger        Corporate      0.00
# 3         Montebello  Elizabeth Moffitt         Consumer      0.08
# 4               Napa  Alan Schoenberger        Corporate      0.07
# ...              ...                ...              ...       ...
# 8394       Fairfield      Tony Molinari        Corporate      0.10
# 8395  Harker Heights    Matt Hagelstein      Home Office      0.09
# 8396       Riverview      Theresa Swint         Consumer      0.10
# 8397   Nicholasville    Maribeth Yedwab      Home Office      0.09
# 8398   Nicholasville    Maribeth Yedwab      Home Office      0.00
#
#       Number of Records Order Date  Order ID Order Priority  Order Quantity  \
# 0                     1 2012-01-01     28774           High              32
# ...

# %% [markdown]
# - coulumn product container elimination

# %%
d.drop(['Product Container'],axis=1,inplace=True)

# %%
d
# Out:
#                 City      Customer Name Customer Segment  Discount  \
# 0         McKeesport     Jessica Myrick   Small Business      0.10
# 1              Bowie     Matt Collister      Home Office      0.08
# 2               Napa  Alan Schoenberger        Corporate      0.00
# 3         Montebello  Elizabeth Moffitt         Consumer      0.08
# 4               Napa  Alan Schoenberger        Corporate      0.07
# ...              ...                ...              ...       ...
# 8394       Fairfield      Tony Molinari        Corporate      0.10
# 8395  Harker Heights    Matt Hagelstein      Home Office      0.09
# 8396       Riverview      Theresa Swint         Consumer      0.10
# 8397   Nicholasville    Maribeth Yedwab      Home Office      0.09
# 8398   Nicholasville    Maribeth Yedwab      Home Office      0.00
#
#       Number of Records Order Date  Order ID Order Priority  Order Quantity  \
# 0                     1 2012-01-01     28774           High              32
# ...

# %% [markdown]
# - zip code column elimiation

# %%
d.drop(['Zip Code'],axis=1,inplace=True)

# %%
d
# Out:
#                 City      Customer Name Customer Segment  Discount  \
# 0         McKeesport     Jessica Myrick   Small Business      0.10
# 1              Bowie     Matt Collister      Home Office      0.08
# 2               Napa  Alan Schoenberger        Corporate      0.00
# 3         Montebello  Elizabeth Moffitt         Consumer      0.08
# 4               Napa  Alan Schoenberger        Corporate      0.07
# ...              ...                ...              ...       ...
# 8394       Fairfield      Tony Molinari        Corporate      0.10
# 8395  Harker Heights    Matt Hagelstein      Home Office      0.09
# 8396       Riverview      Theresa Swint         Consumer      0.10
# 8397   Nicholasville    Maribeth Yedwab      Home Office      0.09
# 8398   Nicholasville    Maribeth Yedwab      Home Office      0.00
#
#       Number of Records Order Date  Order ID Order Priority  Order Quantity  \
# 0                     1 2012-01-01     28774           High              32
# ...

# %% [markdown]
# - order date column elimination

# %%
d.drop(['Order Date'],axis=1,inplace=True)

# %%
d
# Out:
#                 City      Customer Name Customer Segment  Discount  \
# 0         McKeesport     Jessica Myrick   Small Business      0.10
# 1              Bowie     Matt Collister      Home Office      0.08
# 2               Napa  Alan Schoenberger        Corporate      0.00
# 3         Montebello  Elizabeth Moffitt         Consumer      0.08
# 4               Napa  Alan Schoenberger        Corporate      0.07
# ...              ...                ...              ...       ...
# 8394       Fairfield      Tony Molinari        Corporate      0.10
# 8395  Harker Heights    Matt Hagelstein      Home Office      0.09
# 8396       Riverview      Theresa Swint         Consumer      0.10
# 8397   Nicholasville    Maribeth Yedwab      Home Office      0.09
# 8398   Nicholasville    Maribeth Yedwab      Home Office      0.00
#
#       Number of Records  Order ID Order Priority  Order Quantity  \
# 0                     1     28774           High              32
# ...

# %% [markdown]
# - ship date column elimination

# %%
d.drop(['Ship Date'],axis=1,inplace=True)

# %%
d
# Out:
#                 City      Customer Name Customer Segment  Discount  \
# 0         McKeesport     Jessica Myrick   Small Business      0.10
# 1              Bowie     Matt Collister      Home Office      0.08
# 2               Napa  Alan Schoenberger        Corporate      0.00
# 3         Montebello  Elizabeth Moffitt         Consumer      0.08
# 4               Napa  Alan Schoenberger        Corporate      0.07
# ...              ...                ...              ...       ...
# 8394       Fairfield      Tony Molinari        Corporate      0.10
# 8395  Harker Heights    Matt Hagelstein      Home Office      0.09
# 8396       Riverview      Theresa Swint         Consumer      0.10
# 8397   Nicholasville    Maribeth Yedwab      Home Office      0.09
# 8398   Nicholasville    Maribeth Yedwab      Home Office      0.00
#
#       Number of Records  Order ID Order Priority  Order Quantity  \
# 0                     1     28774           High              32
# ...

# %% [markdown]
# #### fetching statistical information about the data

# %%
d.describe()
# Out:
#           Discount  Number of Records  Order Quantity  Product Base Margin  \
# count  8399.000000             8399.0     8399.000000          8336.000000
# mean      0.049671                1.0       25.571735             0.512513
# std       0.031823                0.0       14.481071             0.135589
# min       0.000000                1.0        1.000000             0.350000
# 25%       0.020000                1.0       13.000000             0.380000
# 50%       0.050000                1.0       26.000000             0.520000
# 75%       0.080000                1.0       38.000000             0.590000
# max       0.250000                1.0       50.000000             0.850000
#
#              Profit         Sales  Shipping Cost   Unit Price
# count   8399.000000   8399.000000    8399.000000  8399.000000
# mean     181.184422   1775.878179      12.838557    89.346259
# std     1196.653326   3585.050525      17.264052   290.354383
# ...

# %%
d
# Out:
#                 City      Customer Name Customer Segment  Discount  \
# 0         McKeesport     Jessica Myrick   Small Business      0.10
# 1              Bowie     Matt Collister      Home Office      0.08
# 2               Napa  Alan Schoenberger        Corporate      0.00
# 3         Montebello  Elizabeth Moffitt         Consumer      0.08
# 4               Napa  Alan Schoenberger        Corporate      0.07
# ...              ...                ...              ...       ...
# 8394       Fairfield      Tony Molinari        Corporate      0.10
# 8395  Harker Heights    Matt Hagelstein      Home Office      0.09
# 8396       Riverview      Theresa Swint         Consumer      0.10
# 8397   Nicholasville    Maribeth Yedwab      Home Office      0.09
# 8398   Nicholasville    Maribeth Yedwab      Home Office      0.00
#
#       Number of Records Order Priority  Order Quantity  Product Base Margin  \
# 0                     1           High              32                 0.68
# ...

# %% [markdown]
# #### Statistical information about both qualitative and quantitative data

# %%
d.describe(include="all")
# Out:
#                City Customer Name Customer Segment     Discount  \
# count          8399          8399             8399  8399.000000
# unique         1421           795                4          NaN
# top     Springfield   Darren Budd        Corporate          NaN
# freq             31            41             3076          NaN
# mean            NaN           NaN              NaN     0.049671
# std             NaN           NaN              NaN     0.031823
# min             NaN           NaN              NaN     0.000000
# 25%             NaN           NaN              NaN     0.020000
# 50%             NaN           NaN              NaN     0.050000
# 75%             NaN           NaN              NaN     0.080000
# max             NaN           NaN              NaN     0.250000
#
#         Number of Records Order Priority  Order Quantity  Product Base Margin  \
# count              8399.0           8399     8399.000000          8336.000000
# ...

# %% [markdown]
# #### Duplicate value detection

# %%
d.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Eliminating if any duplicate value is there(here is no duplicate value)

# %%
df=d.drop_duplicates()

# %%
df
# Out:
#                 City      Customer Name Customer Segment  Discount  \
# 0         McKeesport     Jessica Myrick   Small Business      0.10
# 1              Bowie     Matt Collister      Home Office      0.08
# 2               Napa  Alan Schoenberger        Corporate      0.00
# 3         Montebello  Elizabeth Moffitt         Consumer      0.08
# 4               Napa  Alan Schoenberger        Corporate      0.07
# ...              ...                ...              ...       ...
# 8394       Fairfield      Tony Molinari        Corporate      0.10
# 8395  Harker Heights    Matt Hagelstein      Home Office      0.09
# 8396       Riverview      Theresa Swint         Consumer      0.10
# 8397   Nicholasville    Maribeth Yedwab      Home Office      0.09
# 8398   Nicholasville    Maribeth Yedwab      Home Office      0.00
#
#       Number of Records  Order ID Order Priority  Order Quantity  \
# 0                     1     28774           High              32
# ...

# %% [markdown]
# #### Rename the existing column with a new name

# %%
df.rename(columns={"Order Priority":"Order importance"},inplace=True)

# %%
df
# Out:
#                 City      Customer Name Customer Segment  Discount  \
# 0         McKeesport     Jessica Myrick   Small Business      0.10
# 1              Bowie     Matt Collister      Home Office      0.08
# 2               Napa  Alan Schoenberger        Corporate      0.00
# 3         Montebello  Elizabeth Moffitt         Consumer      0.08
# 4               Napa  Alan Schoenberger        Corporate      0.07
# ...              ...                ...              ...       ...
# 8394       Fairfield      Tony Molinari        Corporate      0.10
# 8395  Harker Heights    Matt Hagelstein      Home Office      0.09
# 8396       Riverview      Theresa Swint         Consumer      0.10
# 8397   Nicholasville    Maribeth Yedwab      Home Office      0.09
# 8398   Nicholasville    Maribeth Yedwab      Home Office      0.00
#
#       Number of Records  Order ID Order importance  Order Quantity  \
# 0                     1     28774             High              32
# ...

# %% [markdown]
# #### Rename the column name

# %%
df.rename(columns={"Product Base Margin":"Base margin"},inplace=True)

# %%
df
# Out:
#                 City      Customer Name Customer Segment  Discount  \
# 0         McKeesport     Jessica Myrick   Small Business      0.10
# 1              Bowie     Matt Collister      Home Office      0.08
# 2               Napa  Alan Schoenberger        Corporate      0.00
# 3         Montebello  Elizabeth Moffitt         Consumer      0.08
# 4               Napa  Alan Schoenberger        Corporate      0.07
# ...              ...                ...              ...       ...
# 8394       Fairfield      Tony Molinari        Corporate      0.10
# 8395  Harker Heights    Matt Hagelstein      Home Office      0.09
# 8396       Riverview      Theresa Swint         Consumer      0.10
# 8397   Nicholasville    Maribeth Yedwab      Home Office      0.09
# 8398   Nicholasville    Maribeth Yedwab      Home Office      0.00
#
#       Number of Records  Order ID Order importance  Order Quantity  \
# 0                     1     28774             High              32
# ...

# %% [markdown]
# #### Any 4 sample data is fetching from the data

# %%
df.sample(4)
# Out:
#                City    Customer Name Customer Segment  Discount  \
# 3378  Grand Prairie    Kelly Lampkin        Corporate      0.01
# 4928        Dundalk  Helen Wasserman      Home Office      0.08
# 2607         Denver      Fred Harton      Home Office      0.05
# 1769       Stoneham   Sara Luxemburg   Small Business      0.03
#
#       Number of Records Order importance  Order Quantity  Base margin  \
# 3378                  1         Critical              40         0.38
# 4928                  1             High               2         0.74
# 2607                  1             High              18         0.36
# 1769                  1             High              45         0.37
#
#      Product Category                                       Product Name  \
# 3378  Office Supplies  Snap-A-Way® Black Print Carbonless Ruled Speed...
# 4928        Furniture  Eldon Cleatmat Plus™ Chair Mats for High Pile ...
# ...

# %% [markdown]
# #### Unique value identifing

# %%
df.nunique()
# Out:
# City                 1421
# Customer Name         795
# Customer Segment        4
# Discount               16
# Number of Records       1
# Order importance        5
# Order Quantity         50
# Base margin            51
# Product Category        3
# Product Name         1263
# Profit               7967
# Sales                8153
# Ship Mode               3
# Shipping Cost         652
# State                  48
# Unit Price            751
# dtype: int64

# %% [markdown]
# #### FInding correlation between column

# %%
df.corr()
# Out:
#                    Discount  Number of Records  Order Quantity  Base margin  \
# Discount           1.000000                NaN       -0.009649     0.004079
# Number of Records       NaN                NaN             NaN          NaN
# Order Quantity    -0.009649                NaN        1.000000     0.007839
# Base margin        0.004079                NaN        0.007839     1.000000
# Profit            -0.037128                NaN        0.194655    -0.112985
# Sales             -0.019686                NaN        0.220582     0.156759
# Shipping Cost     -0.001956                NaN       -0.011457     0.373826
# Unit Price         0.001332                NaN       -0.104284     0.057838
#
#                      Profit     Sales  Shipping Cost  Unit Price
# Discount          -0.037128 -0.019686      -0.001956    0.001332
# Number of Records       NaN       NaN            NaN         NaN
# Order Quantity     0.194655  0.220582      -0.011457   -0.104284
# ...

# %% [markdown]
# ##### A positive correlation exists when two variables operate in unison so that when one variable rises or falls, the other does the same. A negative correlation is when two variables move opposite one another so that when one variable rises, the other falls.

# %% [markdown]
# ##### conclusion

# %% [markdown]
# - Discount have  have  negative correlation with order quantity profit sales and shipping cost negative.
# - Dicount have positive correlation with base margin but that is not a strong correlation.
# - Order quantity have positive correlation with base margin profit and sales.
# - order qntity have negative coreelation with shipping cost and unit price.
# - Base margin heve positive correlation with order quantity sales,profit shipping cost and unit price.But they are not strong corrlation.
# - Base margin have negative correlation with profit only
# - profit have positive correlation between order quantity and sales
# - prfit have negative correlation with discount basemargin shipping cost and unitprice
# - shipping cost have positive correlation with basemargin,sales and unit price
# - shipping cost have negative correlation with discount orderquantity  and profit
# - unit price have positive correlation with discount basemargin sales and shipping cost
# - unit cost have negative correlation with orderquantity  and profit.

# %% [markdown]
# #### Finding covariance between columns

# %%
df.cov()
# Out:
#                    Discount  Number of Records  Order Quantity  Base margin  \
# Discount           0.001013                0.0       -0.004447     0.000018
# Number of Records  0.000000                0.0        0.000000     0.000000
# Order Quantity    -0.004447                0.0      209.701421     0.015406
# Base margin        0.000018                0.0        0.015406     0.018384
# Profit            -1.413890                0.0     3373.145504   -18.261058
# Sales             -2.245958                0.0    11451.591183    76.016263
# Shipping Cost     -0.001074                0.0       -2.864293     0.871850
# Unit Price         0.012311                0.0     -438.478987     2.283598
#
#                          Profit         Sales  Shipping Cost     Unit Price
# Discount          -1.413890e+00 -2.245958e+00      -0.001074       0.012311
# Number of Records  0.000000e+00  0.000000e+00       0.000000       0.000000
# ...

# %% [markdown]
# #### Covariance gives you a positive number if the variables are positively related. we ’ll get a negative number if they are negatively related. A high covariance basically indicates there is a strong relationship between the variables. A low value means there is a weak relationship.

# %% [markdown]
# - Discount is negatively related with order quantity profit sales and shipping cost negative.
# - Dicount positivly related  with base margin .
# - Order quantity have positivly related  with base margin profit and sales.
# - order qntity have negativly related with   shipping cost and unit price.
# - Base margin heve positively related  with order quantity sales,profit shipping cost and unit price.But they are not strong relation.
# - Base margin is negatively related with profit only
# - profit is positively related with order quantity and sales
# - prfit is negatively related with discount basemargin shipping cost and unitprice
# - shipping cost have positively related with basemargin,sales and unit price
# - shipping cost is negatively related with discount orderquantity and profit
# - unit price is positivly related with discount basemargin sales and shipping cost
# - unit cost is negatively correlation with orderquantity and profit.

# %% [markdown]
# #### Statistical analysis of single colum

# %% [markdown]
# - count of single column

# %%
df['Number of Records'].count()
# Out:
# 8399

# %% [markdown]
# - calculating mean value

# %%
df['Sales'].mean()
# Out:
# 1775.8781788308122

# %% [markdown]
# - calculating maximum value

# %%
df['Sales'].max()
# Out:
# 89061.05

# %% [markdown]
# - Calculating minimum value

# %%
df['Sales'].min()
# Out:
# 2.24

# %% [markdown]
# - calculating standard deviation

# %%
df['Sales'].std()
# Out:
# 3585.0505249024254

# %% [markdown]
# #### value_count used to get to find count of each column we mentioning

# %%
df['Product Name'].value_counts()
# Out:
# Global High-Back Leather Tilter, Burgundy                                                24
# BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables                        22
# Master Giant Foot® Doorstop, Safety Yellow                                               22
# Bevis 36 x 72 Conference Tables                                                          22
# Fiskars® Softgrip Scissors                                                               22
#                                                                                          ..
# Sauder Camden County Barrister Bookcase, Planked Cherry Finish                            1
# Fellowes 8 Outlet Superior Workstation Surge Protector w/o Phone/Fax/Modem Protection     1
# Epson C62 Color Inkjet Printer                                                            1
# Computer Printout Index Tabs                                                              1
# ...

# %%
df['Product Name'].unique()
# Out:
# array(['Perma STOR-ALL™ Hanging File Box, 13 1/8"W x 12 1/4"D x 10 1/2"H',
#        'Safco Industrial Wire Shelving',
#        'Hon 4070 Series Pagoda™ Armless Upholstered Stacking Chairs', ...,
#        'Accessory1', 'Global Comet™ Stacking Armless Chair',
#        'Epson FX-2180 Wide Format Dot Matrix Printer'], dtype=object)

# %%
df['Order importance'].unique()
# Out:
# array(['High', 'Not Specified', 'Low', 'Critical', 'Medium'], dtype=object)

# %% [markdown]
# #### pivot table creation by using diferent columns and operations

# %%
d=df.copy()
d=df.pivot_table('Profit',columns='Customer Segment',aggfunc='sum')
d
# Out:
# Customer Segment       Consumer      Corporate    Home Office  Small Business
# Profit            287959.983779  599745.924158  318354.095491   315707.956153

# %%
d=df.copy()
d=df.pivot_table('Profit',columns='State',aggfunc='sum')
d
# Out:
# State     Alabama   Arizona    Arkansas  California    Colorado  Connecticut  \
# Profit  53629.986  39829.33  39850.2862  87355.5292  20386.2005  6885.144914
#
# State   Delaware     Florida     Georgia       Idaho  ...  South Dakota  \
# Profit  585.3514  82571.9497  45113.2937  15004.2193  ...     19756.612
#
# State    Tennessee      Texas        Utah     Vermont    Virginia  Washington  \
# Profit  17549.8522  93571.526  23151.6703  6378.92945  61721.9272  41995.7833
#
# State   West Virginia  Wisconsin   Wyoming
# Profit    1227.608123  34440.907  7384.856
#
# [1 rows x 48 columns]

# %%
d=df.copy()
d=df.pivot_table('Discount',columns='Customer Segment',aggfunc='sum')
d
# Out:
# Customer Segment  Consumer  Corporate  Home Office  Small Business
# Discount             82.29     153.31       100.47           81.12

# %%
d4=df.copy()

# %%
d4
# Out:
#                 City      Customer Name Customer Segment  Discount  \
# 0         McKeesport     Jessica Myrick   Small Business      0.10
# 1              Bowie     Matt Collister      Home Office      0.08
# 2               Napa  Alan Schoenberger        Corporate      0.00
# 3         Montebello  Elizabeth Moffitt         Consumer      0.08
# 4               Napa  Alan Schoenberger        Corporate      0.07
# ...              ...                ...              ...       ...
# 8394       Fairfield      Tony Molinari        Corporate      0.10
# 8395  Harker Heights    Matt Hagelstein      Home Office      0.09
# 8396       Riverview      Theresa Swint         Consumer      0.10
# 8397   Nicholasville    Maribeth Yedwab      Home Office      0.09
# 8398   Nicholasville    Maribeth Yedwab      Home Office      0.00
#
#       Number of Records Order importance  Order Quantity  Base margin  \
# 0                     1             High              32         0.68
# ...

# %% [markdown]
# #### Making the profit column with the product of sales and order quantity

# %%
d4['profit']=df['Sales']*df['Order Quantity']
d4['profit']
# Out:
# 0         5771.52
# 1         7852.32
# 2         4956.24
# 3        26436.40
# 4       175577.17
#           ...
# 8394     15683.50
# 8395      9526.02
# 8396       141.50
# 8397       803.33
# 8398     20860.83
# Name: profit, Length: 8399, dtype: float64

# %%
d4
# Out:
#                 City      Customer Name Customer Segment  Discount  \
# 0         McKeesport     Jessica Myrick   Small Business      0.10
# 1              Bowie     Matt Collister      Home Office      0.08
# 2               Napa  Alan Schoenberger        Corporate      0.00
# 3         Montebello  Elizabeth Moffitt         Consumer      0.08
# 4               Napa  Alan Schoenberger        Corporate      0.07
# ...              ...                ...              ...       ...
# 8394       Fairfield      Tony Molinari        Corporate      0.10
# 8395  Harker Heights    Matt Hagelstein      Home Office      0.09
# 8396       Riverview      Theresa Swint         Consumer      0.10
# 8397   Nicholasville    Maribeth Yedwab      Home Office      0.09
# 8398   Nicholasville    Maribeth Yedwab      Home Office      0.00
#
#       Number of Records Order importance  Order Quantity  Base margin  \
# 0                     1             High              32         0.68
# ...

# %% [markdown]
# #### groupby statement implementation

# %%
d4=d4.groupby(['Product Category'])['Sales'].sum() ##groupby category printing sum of sales in the form of data frame
d4=pd.DataFrame(d4)
d4
# Out:
#                         Sales
# Product Category
# Furniture         5178590.542
# Office Supplies   3752762.100
# Technology        5984248.182

# %% [markdown]
# ####  grouping the product category with sum of sales and the resulting value is making in asending order

# %%
n=df.groupby('Product Category').Sales.sum().sort_values(ascending=False)##groupby the categor and printing sum of sales in descending orde
n
# Out:
# Product Category
# Technology         5984248.182
# Furniture          5178590.542
# Office Supplies    3752762.100
# Name: Sales, dtype: float64

# %%
n=df.groupby('Product Category').Sales.sum().sort_values(ascending=False)
n
# Out:
# Product Category
# Technology         5984248.182
# Furniture          5178590.542
# Office Supplies    3752762.100
# Name: Sales, dtype: float64

# %%
n.head()
# Out:
# Product Category
# Technology         5984248.182
# Furniture          5178590.542
# Office Supplies    3752762.100
# Name: Sales, dtype: float64

# %% [markdown]
# #### Creating crosstab with diferent columns

# %%
pd.crosstab(df['Order importance'],df['State'])
# Out:
# State             Alabama  Arizona  Arkansas  California  Colorado  \
# Order importance
# Critical               25       33        20         151        22
# High                   29       22        28         158        53
# Low                    21       34        24         159        37
# Medium                 25       20        21         138        32
# Not Specified          25       25        30         174        33
#
# State             Connecticut  Delaware  Florida  Georgia  Idaho  ...  \
# Order importance                                                  ...
# Critical                   13         6       78       36     18  ...
# High                       12         0      102       36     30  ...
# Low                        22         2      103       44     24  ...
# Medium                     20         3      120       25     18  ...
# Not Specified              15         4       76       40     24  ...
#
# ...

# %% [markdown]
# #### Sorting the coulumn values

# %%
df.sort_values(by=['Product Category'])
# Out:
#                  City       Customer Name Customer Segment  Discount  \
# 1877         Longview       Tonja Turnell         Consumer      0.00
# 2051           Olathe         Angele Hood         Consumer      0.07
# 2052          Liberal      Lisa DeCherney        Corporate      0.06
# 5088      Clarksville      Randy Ferguson      Home Office      0.03
# 7884          Baytown         Darren Budd         Consumer      0.05
# ...               ...                 ...              ...       ...
# 4466      Beavercreek        Tony Chapman         Consumer      0.04
# 4467        Hempstead  Justin MacKendrick        Corporate      0.04
# 4471  University City        Guy Thornton        Corporate      0.08
# 4431        El Mirage          Anna Chung      Home Office      0.05
# 8398    Nicholasville     Maribeth Yedwab      Home Office      0.00
#
#       Number of Records Order importance  Order Quantity  Base margin  \
# ...

# %% [markdown]
# #### Creating pivot table and arithmetic operration

# %%
state_sales_d=pd.pivot_table(data=df[['State','Sales']],index=['State'],values='Sales',aggfunc='max')

# %%
state_sales_d
# Out:
#                      Sales
# State
# Alabama         89061.0500
# Arizona         17599.3900
# Arkansas        29345.2700
# California      29884.6000
# Colorado        22319.5800
# Connecticut     12098.8700
# Delaware         2690.7515
# Florida         23300.1200
# Georgia         24559.9100
# Idaho           19014.2400
# Illinois        26133.3900
# Indiana         23255.6100
# Iowa            19109.6100
# Kansas          27875.5400
# Kentucky        21532.2600
# Louisiana       29186.4900
# MA              26622.5500
# MO              18056.6800
# Maine           21717.3600
# Maryland        24701.1200
# Michigan        27663.9200
# Minnesota       28761.5200
# Mississippi     15655.2400
# Montana         19707.2000
# Nebraska        15383.7000
# Nevada          14665.1500
# New Hampshire   13382.0100
# New Jersey      24391.1600
# New Mexico      24639.8000
# New York        45923.7600
# North Carolina  41343.2100
# North Dakota     9473.3100
# Ohio            23106.4600
# ...

# %% [markdown]
# #### sorting the value of sales in ascending order

# %%
state_sales_d.sort_values(by="Sales",ascending=False).head(10)
# Out:
#                    Sales
# State
# Alabama         89061.05
# New York        45923.76
# North Carolina  41343.21
# California      29884.60
# Arkansas        29345.27
# Louisiana       29186.49
# Minnesota       28761.52
# Oregon          28389.14
# Kansas          27875.54
# Washington      27720.98

# %% [markdown]
# #### Making pivot table using index as state and value profit then operation applied is maximum

# %%
state_profit_d=pd.pivot_table(data=df[['State','Profit']],
                            index=['State'],
                            values='Profit',
                            aggfunc='max')

state_profit_d.sort_values(by='Profit',ascending=False).head(10)
# Out:
#                 Profit
# State
# Alabama     27220.6900
# Louisiana   14440.3900
# Arkansas    13340.2600
# California  12748.8600
# Oregon      12606.8100
# Washington  11984.3950
# New York    11630.1460
# Illinois    10951.3065
# Oklahoma     9791.0410
# Ohio         9527.4715

# %%
d_Category_sales=pd.pivot_table(data=df[['Product Name','Product Category','Sales']],index=['Product Name','Product Category'],values='Sales',aggfunc="max")
d_Category_sales
# Out:
#                                    Sales
# Product Name Product Category
# 232          Technology        5023.2535
# 252          Technology        2766.8180
# 282          Technology        3931.3180
# 636          Technology        4509.3775
# 688          Technology        8221.2935
# ...                                  ...
# i500plus     Technology        2482.0340
# i600         Technology        1702.4990
# iDEN i550    Technology        6264.1855
# iDEN i95     Technology        2628.0470
# iDENi80s     Technology        2679.1235
#
# [1263 rows x 1 columns]

# %% [markdown]
# #### Adding new column in existing data

# %%
df['Revenue']=df['Sales']-df['Profit']

# %%
df
# Out:
#                 City      Customer Name Customer Segment  Discount  \
# 0         McKeesport     Jessica Myrick   Small Business      0.10
# 1              Bowie     Matt Collister      Home Office      0.08
# 2               Napa  Alan Schoenberger        Corporate      0.00
# 3         Montebello  Elizabeth Moffitt         Consumer      0.08
# 4               Napa  Alan Schoenberger        Corporate      0.07
# ...              ...                ...              ...       ...
# 8394       Fairfield      Tony Molinari        Corporate      0.10
# 8395  Harker Heights    Matt Hagelstein      Home Office      0.09
# 8396       Riverview      Theresa Swint         Consumer      0.10
# 8397   Nicholasville    Maribeth Yedwab      Home Office      0.09
# 8398   Nicholasville    Maribeth Yedwab      Home Office      0.00
#
#       Number of Records Order importance  Order Quantity  Base margin  \
# 0                     1             High              32         0.68
# ...

# %% [markdown]
# #### Changing value in a column using arithmetic operation

# %%
df['Grossprice']=(df['Revenue']-df['Profit'])/df['Order Quantity']

# %%
df
# Out:
#                 City      Customer Name Customer Segment  Discount  \
# 0         McKeesport     Jessica Myrick   Small Business      0.10
# 1              Bowie     Matt Collister      Home Office      0.08
# 2               Napa  Alan Schoenberger        Corporate      0.00
# 3         Montebello  Elizabeth Moffitt         Consumer      0.08
# 4               Napa  Alan Schoenberger        Corporate      0.07
# ...              ...                ...              ...       ...
# 8394       Fairfield      Tony Molinari        Corporate      0.10
# 8395  Harker Heights    Matt Hagelstein      Home Office      0.09
# 8396       Riverview      Theresa Swint         Consumer      0.10
# 8397   Nicholasville    Maribeth Yedwab      Home Office      0.09
# 8398   Nicholasville    Maribeth Yedwab      Home Office      0.00
#
#       Number of Records Order importance  Order Quantity  Base margin  \
# 0                     1             High              32         0.68
# ...

# %% [markdown]
# ### DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Bar graph plotting

# %%
plt.bar(df['Order Quantity'],df["Profit"])
plt.title("Profit vs Quantity",fontsize=15,color="red")
plt.xlabel("Quantity",fontsize=15)
plt.ylabel("Profit",fontsize=15)
plt.grid(True)
plt.show()

# %% [markdown]
# #### Ploting a bar graph is helpful to compare data among different category.
# #### Longer the bar greater the value

# %% [markdown]
# - Here quantity between 10 and 20 have highest profit compared to other details.
# - Lowest profit in the range between 0 to 10

# %%
plt.figure(figsize=(18,5))
plt.bar('Product Category','Profit',data=df,color='orange')
plt.show()

# %% [markdown]
# #### conclusion

# %% [markdown]
# - plotting bargraph using profit and product category

# %% [markdown]
# - Here we are plotting bar graph based on the profit from the graph we can assume that the technology have more profit compared to other category like office supplies and furniture.

# %%
print(df['State'].value_counts())
# Out:
# California        780
# Texas             577
# Illinois          500
# Florida           479
# Ohio              396
# New York          372
# Michigan          291
# Indiana           241
# Washington        240
# Minnesota         239
# Pennsylvania      219
# North Carolina    211
# Virginia          198
# Georgia           181
# Maryland          178
# Colorado          177
# New Jersey        177
# Wisconsin         169
# Oregon            168
# Tennessee         166
# MO                161
# Iowa              156
# MA                150
# Utah              146
# Arizona           134
# Kansas            133
# Maine             128
# Alabama           125
# Arkansas          123
# Idaho             114
# South Carolina    105
# Oklahoma          104
# Louisiana          89
# New Mexico         84
# Kentucky           83
# Connecticut        82
# Mississippi        78
# Nebraska           77
# Vermont            61
# New Hampshire      54
# Montana            49
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(15,4))
sns.countplot(x=df["State"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### conclusion

# %% [markdown]
# - countplot() method is used to Show the counts of observations in each categorical bin using bars.
# - Here we an find that the highest count is in california compared to other country
# - Lowest count i the country Delaware

# %%
plt.bar(df['Order Quantity'],df['Sales'],color='red')
plt.title('sales vs quantity',fontsize=15,color='blue')
plt.xlabel('Quantity',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.show()

# %% [markdown]
# #### Conclusion

# %% [markdown]
# - A bar chart represents data in rectangular bars with length of the bar proportional to the value of the variable.
# - Here plotting bar graph using quantity and sales.
# - According to graph we can find out that the highest sale is 80000 and that is in the range between 10 to 20
# - LOwest sale is below 20000 and that is in the range between 0 to 10

# %%
sns.countplot(x="Customer Segment",data=df,palette='coolwarm')
plt.show()

# %% [markdown]
# #### Conclusion

# %% [markdown]
# - countplot() method is used to Show the counts of observations in each categorical bin using bars.
# - plotting graph with customer segment and count
# - corporate hahe high count compared to other customer segment
# - lowest count is in small business.
# - home office and consumer have count less than coperate but higer than small busines

# %% [markdown]
# ### piechart

# %%
plt.title('Customer segment',fontsize=20)
df['Customer Segment'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# #### conclusion

# %% [markdown]
# - A pie chart is a type of graph in which a circle is divided into sectors that each represents a proportion of the whole.
# - Pie charts are a useful way to organize data in order to see the size of components relative to the whole, and are particularly good at showing percentage or proportional data.
# - plotting customer segment in piechart
# - From this we can find that 36.6% is covered by corperate
# - least proportion have 19.5% thet is the small busines segment
# - Home office covered 24.2%
# - REmaining 19.6% proportion is taken by consumers

# %%
sns.countplot(x="Product Category",data=df,palette="tab10")
plt.show()

# %% [markdown]
# - countplot() method is used to Show the counts of observations in each categorical bin using bars.
#  - plotting graph with product category  and count
#  - office supplies have highest count compared to other two category
#  - furniture catogory is lesser count

# %%
df.groupby("Customer Segment")[["Profit","Sales"]].sum().plot.bar(color=["red","blue"],figsize=(8,5))
plt.ylabel("Profit/Loss and Sales")
plt.show()

# %% [markdown]
# #### conclusion

# %% [markdown]
# - Here plotting graph using custumer segment and profit/loss
# - corperate have the highest sale compared to other segment
# - small busines have the lowest sale among 4 segment
# - Highr the sale higher the profit,so the corperate have highest sale as well as highest profit
# - small business have low sales and low profit

# %%
plt.title("Category",fontsize=20)
df['Product Category'].value_counts().plot.pie(autopct="%1.1f%%",shadow=True)
plt.show()

# %% [markdown]
# #### conclusion

# %% [markdown]
# - Here is 3 product category one is furniture other office supplies and then technology
# - office supplies is large in proportion compared to other two category
# - furniture is lowest proportion in entrire category that is only 20.5%

# %%
plt.figure(figsize=(12,8))
plt.title("SEGMENT WISE SALES")
sns.barplot(x="Customer Segment",y="Sales",data=df,hue='Customer Segment',palette="coolwarm_r")
plt.xlabel("Category",fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15,12))
sns.countplot(x='State',data=df,palette='rocket_r',order=df['State'].value_counts().index)
plt.xlabel('States',fontsize=25)
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# #### Conclusion

# %% [markdown]
# - countplot() method is used to Show the counts of observations in each categorical bin using bars.
# - california have highest count compared to other country
# - lowest count have the country Delaware

# %% [markdown]
# #### Heatmap representation

# %%
n_data=['Sales','Order Quantity','Discount','Profit']
plt.figure(figsize=(10,5))
sns.heatmap(df[n_data].corr(),annot=True,fmt='.4f',cmap='coolwarm_r',center=0)
plt.show()

# %% [markdown]
# #### Conclusion

# %% [markdown]
# - A heat map is data analysis software that uses color the way a bar graph uses height and width
# -  A heat map shows you in a visual way that's easy to assimilate and make decisions from.
# - If sales increases profit automaticlly increase
# - discount increases the profit and sale will increase automatically

# %% [markdown]
# #### Lineplot

# %%
plt.figure(figsize=(10,4))
sns.lineplot("Discount","Profit",data=df,color="r",label="Discount")
plt.legend()
plt.show()

# %% [markdown]
# #### conclusion

# %% [markdown]
# - A line plot is nothing but the different data points connected with a line.
# - Line plots are generally used to track the changes over a period of time.
# - Sometimes, it is also used to compare the changes over a time period for different groups
# - If the discount increases the profit automatically increases
# - The highest profit gained during the discount range 0.00 to 0.05

# %% [markdown]
# #### Histogram representation

# %%
df.hist(bins=20,figsize=(20,15),color="red")
plt.show()

# %%
df.hist(bins=50,figsize=(20,15),color="red")
plt.show()

# %% [markdown]
# #### Pairplot representation

# %%
sns.pairplot(df,hue="Product Category")
plt.show()
